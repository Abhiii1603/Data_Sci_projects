# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/crop-classification/data/jute/jute025a.jpeg
# /kaggle/input/crop-classification/data/jute/jute002ahs.jpeg
# /kaggle/input/crop-classification/data/jute/jute018ahs.jpeg
# /kaggle/input/crop-classification/data/jute/jute035ahs.jpeg
# /kaggle/input/crop-classification/data/jute/jute040arot.jpeg
# /kaggle/input/crop-classification/data/jute/jute007ahs.jpeg
# /kaggle/input/crop-classification/data/jute/jute001a.jpeg
# /kaggle/input/crop-classification/data/jute/jute031arot.jpeg
# /kaggle/input/crop-classification/data/jute/jute003ahf.jpeg
# /kaggle/input/crop-classification/data/jute/jute008a.jpeg
# /kaggle/input/crop-classification/data/jute/jute019ahf.jpeg
# /kaggle/input/crop-classification/data/jute/jute002ahf.jpeg
# /kaggle/input/crop-classification/data/jute/jute028ahf.jpeg
# /kaggle/input/crop-classification/data/jute/jute007ahf.jpeg
# /kaggle/input/crop-classification/data/jute/jute027arot.jpeg
# /kaggle/input/crop-classification/data/jute/jute017a.jpeg
# ...

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.applications import VGG16
from tensorflow.keras.layers import Dense, MaxPooling2D, Flatten
import os

# %%
dataset_path = "/kaggle/input/crop-classification/data"
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[150], line 2
#       1 dataset_path = "/kaggle/input/crop-classification/data"
# ----> 2 data
#
# NameError: name 'data' is not defined

# %%
categories = os.listdir(dataset_path)
final_model = keras.Sequential([
    backbone_model,
    keras.layers.Flatten(),
    keras.layers.Dense(64, activation="tanh"),
    keras.layers.Dense(32, activation="tanh"),
    keras.layers.Dense(16, activation="tanh"),
    keras.layers.Dense(len(categories), activation="softmax")
])

# %%
size_of_image = (224, 224)

# %%
num_of_classes = 5

# %%
crop_image_ds = image_dataset_from_directory(dataset_path, labels = "inferred", image_size=size_of_image)

# %%
backbone_model = VGG16(weights = "imagenet", include_top= False, input_shape= (224, 224, 3))

# %%
backbone_model.layers

# %%
backbone_model.trainable = False

# %%
# final_model = Sequential([
#     backbone_model,
#     Flatten(),
#     Dense(len(categories), activation="softmax")
    
# ])
final_model = Sequential([
    backbone_model,
    Flatten(),
    
    Dense(64, activation="tanh"),
    
    Dense(32, activation="tanh"),
    
    Dense(16, activation="tanh"),
    
    Dense(5, activation="softmax")
])

# %%
final_model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics="accuracy"
)
final_model.summary()
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  efficientnetb0 (Functional)  (None, 7, 7, 1280)       4049571
#
#  flatten_14 (Flatten)        (None, 62720)             0
#
#  dense_51 (Dense)            (None, 64)                4014144
#
#  dense_52 (Dense)            (None, 32)                2080
#
#  dense_53 (Dense)            (None, 16)                528
#
#  dense_54 (Dense)            (None, 5)                 85
#
# ...
# Total params: 8,066,408
# Trainable params: 4,016,837
# Non-trainable params: 4,049,571
# _________________________________________________________________

# %%
final_model.evaluate(crop_image_ds)
# Out:
# 26/26 [==============================] - 4s 61ms/step - loss: 1.8059 - accuracy: 0.1803
# [1.805875539779663, 0.1803482621908188]

# %%
final_model.fit(crop_image_ds, batch_size=8, epochs=8, shuffle=True)
# Out:
# Epoch 1/8
# 26/26 [==============================] - 2s 64ms/step - loss: 0.5538 - accuracy: 0.8731
# Epoch 2/8
# 26/26 [==============================] - 2s 63ms/step - loss: 0.3701 - accuracy: 0.9453
# Epoch 3/8
# 26/26 [==============================] - 2s 63ms/step - loss: 0.2417 - accuracy: 0.9789
# Epoch 4/8
# 26/26 [==============================] - 2s 64ms/step - loss: 0.1816 - accuracy: 0.9776
# Epoch 5/8
# 26/26 [==============================] - 2s 70ms/step - loss: 0.1325 - accuracy: 0.9876
# Epoch 6/8
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0975 - accuracy: 0.9913
# Epoch 7/8
# 26/26 [==============================] - 2s 63ms/step - loss: 0.0743 - accuracy: 0.9950
# Epoch 8/8
# 26/26 [==============================] - 2s 64ms/step - loss: 0.0562 - accuracy: 0.9950
